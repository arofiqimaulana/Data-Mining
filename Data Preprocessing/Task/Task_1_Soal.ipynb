# %% [markdown]
# # Datasets
# Data ini diambil dari website bps https://www.bps.go.id/statictable/2014/09/08/1003/volume-ekspor-dan-impor-migas-berat-bersih-ribu-ton-1996-2021.html.

# %% [markdown]
# # Pengumpulan tugas
# Tugas dikerjakan di google collab kemudian di share ke email rofiqi@jagoanhosting.com.

# %% [markdown]
# # Task
# 1. Lakukan Import ketiga datasets (beri nama df_gas, df_hasil_minyak,df_minyak_mentah)
# 2. Berapa nilai ekspor minyak mentah di tahun 2012 ?
# 2. Buatlah kolom baru yang merupakan hasil selisih antara eskpor gas dan ekspor hasil minyak ?
# 3. Pada tahun berapa nilai ekspor hasil minyak paling tinggi?

# %% [markdown]
# ### 1. Lakukan Import ketiga datasets (beri nama df_gas, df_hasil_minyak,df_minyak_mentah)

# %%
import pandas as pd

# %%
url1 = 'https://raw.githubusercontent.com/arofiqimaulana/Data-Mining/master/Data%20Preprocessing/Task/Ekspor%20Gas.csv'
url2 = 'https://raw.githubusercontent.com/arofiqimaulana/Data-Mining/master/Data%20Preprocessing/Task/Ekspor%20Hasil%20Minyak.csv'
url3 = 'https://raw.githubusercontent.com/arofiqimaulana/Data-Mining/master/Data%20Preprocessing/Task/Ekspor%20Minyak%20Mentah.csv'

# %% [markdown]
# ### 2. Berapa nilai ekspor minyak mentah di tahun 2012 ?

# %%
# gunakan filtering

# %%
# Out:
# 16    14973
# Name: Ekspor_Minyak_Mentah, dtype: int64

# %% [markdown]
# ### 3. Buatlah kolom baru yang merupakan hasil selisih antara eskpor gas dan ekspor hasil minyak ?

# %%
# hint : gunakan pd.merge

# %%
# Out:
#     Tahun  Ekspor_Gas  Impor_Gas  Ekspor_Hasil_Minyak  Impor_Hasil_Minyak  \
# 0    1996       29344          1                10689               10134
# 1    1997       29016         32                10221               11748
# 2    1998       28954         86                 8436               10941
# 3    1999       30066         26                 7825               12250
# 4    2000       27615         11                 8787               13971
# 5    2001       25236         31                 7008               11751
# 6    2002       27618          0                 7574               15116
# 7    2003       27614         69                 7425               13589
# 8    2004       26594         19                 6800               15972
# 9    2005       24445         23                 5994               21065
# 10   2006       23117         49                 7047               18658
# 11   2007       21271        117                 6265               19476
# ...

# %% [markdown]
# ### 4. Pada tahun berapa nilai ekspor hasil minyak paling tinggi?

# %%
# hint : gunankan perintah .max

# %%
# Out:
#    Tahun  Ekspor_Hasil_Minyak  Impor_Hasil_Minyak
# 0   1996                10689               10134
