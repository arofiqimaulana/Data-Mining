# %%
import pandas as pd

# %%
df_sayuran = pd.read_excel('Import Sayuran.xls')
df_minyak = pd.read_excel('Import Minyak Bumi.xls')
df_pupuk = pd.read_excel('Impor Pupuk.xls')

# %% [markdown]
# # Questions
# 1. Negara yang mengimpor sayuran terbanyak dan terendah di tahun 2017 ?
# 2. Negara yang mengimpor minyak terbanyak dan terendah di tahun 2020 ?
# 3. Berapa total impor sayuran, minyak, pupuk negara australia di sepanjang tahun 2017-2020 ?

# %%
df_pupuk
# Out:
#    Negara Asal    2017    2018    2019    2020    2021
# 0    Tiongkok1  2408.3  2339.2  1914.5  1654.1  1784.5
# 1       Kanada  1266.1  1269.4   963.3  1203.8  1804.2
# 2        Mesir   729.1   794.9   681.3   753.7  1136.2
# 3        Rusia   962.3  1044.1   818.7   743.3   974.6
# 4    Belarusia   660.9   738.8   640.2   568.9   905.5
# 5    Australia   332.9   286.7   185.5   188.3   286.7
# 6     Yordania   257.9   281.3   181.9   155.9   243.7
# 7       Jerman   249.3   156.0   111.8   162.7   151.8
# 8      Vietnam    75.7   112.3    66.5   116.1   183.6
# 9     Malaysia   328.6   344.0    99.2   103.7    88.6
# 10        Laos    44.6    83.3    91.9   148.6    96.4
# 11    Norwegia    22.6    20.8    46.0    51.3    73.5
# 12      Taiwan    27.1    87.9    53.6    26.8    43.1
# 13    Lainnya    562.1   524.4   280.1   371.5   351.3
# 14      Kanada   302.3   362.0   300.9   307.7   545.7
# 15       Rusia   249.7   298.1   257.9   210.7   326.1
# ...

# %%
df_sayuran
# Out:
#         Negara Asal      2010      2011      2012      2013      2014  \
# 0          Myanmar    35458.2   45525.6   47447.5   51324.1   60983.0
# 1             India   37516.7   65237.1   53942.7   63794.1   68495.0
# 2     Selandia Baru   14735.5   16306.9   17683.1   12864.0   24266.4
# 3         Australia   20866.8   29740.5   28232.0   36377.9   32457.2
# 4   Amerika Serikat   17962.2   21799.1   17091.5   16793.4   12897.2
# 5           Belanda    5350.1   11346.2   10398.1      95.3   13132.9
# 6          Ethiopia    2245.2    6225.9    9506.5   14298.5   23242.0
# 7            Jerman      60.9    5282.7    2340.0    7248.4    6617.6
# 8            Kanada   14186.4   20217.6   24478.3   37435.9   22595.0
# 9           Lainnya   80621.3  191754.4  116465.7   63872.4   62704.5
# 10        Tiongkok1  290776.1  343172.6  304854.1  423952.7  424739.6
# 11         Myanmar    28483.6   44185.4   37892.5   47870.1   60420.6
# ...

# %%
df_minyak
# Out:
#         Negara Asal     2017     2018     2019     2020     2021
# 0         Singapura  15840.8  17850.8  13741.8  10466.5  10332.4
# 1          Malaysia   7333.8   4091.3   3543.5   6311.5   5772.9
# 2        Arab Saudi   5487.1   6308.4   5810.5   6009.9   5761.3
# 3   Amerika Serikat    827.8   1875.7   2566.3   2817.3   4062.5
# 4           Nigeria   3407.5   4646.1   3952.6   2313.1   3961.4
# 5   Uni Emirat Arab   3283.7   2003.1   2678.2   2990.8   2114.4
# 6        Australia    2216.3   1159.3   1684.9   1280.2   1597.7
# 7     Korea Selatan   1653.1   2097.3   1932.1    853.3    708.5
# 8         Tiongkok1    526.8    436.2    578.9    631.4    810.0
# 9             Qatar   1412.9   2059.4   1600.9   1326.6    738.9
# 10          Lainnya   8380.3   6688.5   2836.7   2653.5   6266.3
# 11        Singapura   8603.8  11857.8   8120.4   4221.4   6688.8
# 12         Malaysia   3572.3   2435.9   1938.2   2110.6   3771.9
# ...
