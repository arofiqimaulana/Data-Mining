# %%
import pandas as pd
import warnings
import csv
from mlxtend.frequent_patterns import fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Data Preprocesing

# %%
data = [['Milk','Onion','Nutmeg','Kidney Beans','Eggs','Yougurt'],
      ['Dill','Onion','Nutmeg','Kidney Beans','Eggs','Yougurt'],
      ['Milk','Apple','Kidney Beans','Eggs'],
      ['Milk','Unicorn','Corn','Kidney Beans','Yougurt'],
      ['Corn','Onion','Kidney Beans','Ice Cream','Eggs']]

data
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yougurt'],
#  ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yougurt'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yougurt'],
#  ['Corn', 'Onion', 'Kidney Beans', 'Ice Cream', 'Eggs']]

# %%
# Data perlu diubah ke dalam bentuk dataframe
# kolom menunjukkan list unique item, sedangkan baris menunjukkan ada/tidaknya item tersebut

trf = TransactionEncoder()
data_trf = trf.fit(data).transform(data)

df = pd.DataFrame(data_trf,columns=trf.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice Cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yougurt
# 0    False     True
# 1    False     True
# 2    False    False
# 3     True     True
# 4    False    False

# %% [markdown]
# # 2. Modeling

# %% [markdown]
# ## 2.1 Menghitung nilai support

# %%
frequent_itemsets = fpgrowth(df,min_support=0.05, use_colnames=True)
frequent_itemsets.sort_values('support',ascending=False,inplace=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0        1.0                                     (Kidney Beans)
# 11       0.8                               (Kidney Beans, Eggs)
# 1        0.8                                             (Eggs)
# 18       0.6                        (Kidney Beans, Onion, Eggs)
# 15       0.6                                      (Onion, Eggs)
# ..       ...                                                ...
# 69       0.2                                      (Onion, Dill)
# 68       0.2                                     (Nutmeg, Dill)
# 67       0.2  (Nutmeg, Milk, Kidney Beans, Yougurt, Eggs, On...
# 66       0.2        (Nutmeg, Milk, Kidney Beans, Yougurt, Eggs)
# 148      0.2       (Corn, Kidney Beans, Ice Cream, Eggs, Onion)
#
# [149 rows x 2 columns]

# %% [markdown]
# ## 2.2 Pembentukan aturan

# %%
rules1 = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules1.sort_values('lift',ascending=False,inplace=True)
rules1
# Out:
#                         antecedents                          consequents  \
# 516                 (Unicorn, Milk)        (Kidney Beans, Corn, Yougurt)
# 505   (Kidney Beans, Corn, Yougurt)                      (Unicorn, Milk)
# 573      (Kidney Beans, Corn, Milk)                            (Unicorn)
# 524                       (Unicorn)  (Kidney Beans, Corn, Milk, Yougurt)
# 1222     (Kidney Beans, Corn, Eggs)                   (Onion, Ice Cream)
# ...                             ...                                  ...
# 719           (Eggs, Dill, Yougurt)                       (Kidney Beans)
# 726                  (Kidney Beans)                (Eggs, Dill, Yougurt)
# 731          (Onion, Milk, Yougurt)                       (Kidney Beans)
# 734                  (Kidney Beans)               (Onion, Milk, Yougurt)
# 623        (Onion, Ice Cream, Corn)                       (Kidney Beans)
#
#       antecedent support  consequent support  support  confidence  lift  \
# 516                  0.2                 0.2      0.2         1.0   5.0
# 505                  0.2                 0.2      0.2         1.0   5.0
# 573                  0.2                 0.2      0.2         1.0   5.0
# 524                  0.2                 0.2      0.2         1.0   5.0
# 1222                 0.2                 0.2      0.2         1.0   5.0
# ...                  ...                 ...      ...         ...   ...
# 719                  0.2                 1.0      0.2         1.0   1.0
# 726                  1.0                 0.2      0.2         0.2   1.0
# 731                  0.2                 1.0      0.2         1.0   1.0
# 734                  1.0                 0.2      0.2         0.2   1.0
# 623                  0.2                 1.0      0.2         1.0   1.0
#
#       leverage  conviction
# 516       0.16         inf
# 505       0.16         inf
# 573       0.16         inf
# 524       0.16         inf
# 1222      0.16         inf
# ...        ...         ...
# 719       0.00         inf
# 726       0.00         1.0
# 731       0.00         inf
# 734       0.00         1.0
# 623       0.00         inf
#
# [1246 rows x 9 columns]
